# %%
# !git clone https://github.com/ZGCTroy/Domain_Adaptation.git

# %%
import os
os.chdir('/content/Domain_Adaptation')
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime → "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)

# %%
# !git fetch --all
# !git reset --hard origin/master
# !git pull
# Out:
# Fetching origin
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 23 (delta 17), reused 23 (delta 17), pack-reused 0
# Unpacking objects: 100% (23/23), done.
# From https://github.com/ZGCTroy/Domain_Adaptation
#    bfb0ce7..b2fbec0  master     -> origin/master
# HEAD is now at b2fbec0 RTN2
# Already up to date.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
! cp -r /content/drive/My\ Drive/Office31.zip /content/Domain_Adaptation/data/Office31.zip
! unzip -o /content/Domain_Adaptation/data/Office31.zip -d //content/Domain_Adaptation/data/
! cp -r /content/drive/My\ Drive/Digits.zip /content/Domain_Adaptation/data/Digits.zip
! unzip -o /content/Domain_Adaptation/data/Digits.zip -d //content/Domain_Adaptation/data/

# %%
# !pip3 install tensorboardX

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Amazon' --target='Webcam' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
# Out:
# /content/Domain_Adaptation
# Source domain :Amazon, Train Data size:2817 Test Data size:2817
# Target domain :Webcam, Train Data size:795 Test Data size:795
# 2800/2817
# Data size = 2817 , corrects = 64
# loss weight = 1.0
# Initial Train Loss: 0.0000 Acc: 0.0227
#
#
# 784/795
# Data size = 795 , corrects = 22
# loss weight = 1.0
# Initial Test Loss: 0.0000 Acc: 0.0277
#
#
#
# Epoch 0/999998
#  ----------
# iteration : 0
#
# 784/795
#
# Data size = 812 , corrects = 51
# Using 21.268387
# Alpha =  0.021634954242364612
# source loss = 4.0250468254089355, target_loss = 3.629960536956787, target augment loss = 0
# Train Loss: 7.7373 Acc: 0.0628
#
# Cuda : cuda:0 Current Best Test Acc : 0.027673
# Optimizer : SGD Cur lr :  0.00096872471695842
#
#
#
# Epoch 1/999998
#  ----------
# iteration : 29
#
# 784/795
#
# Data size = 812 , corrects = 161
# Using 20.249485
# Alpha =  0.04402099061002618
# source loss = 3.4025583267211914, target_loss = 3.1510868072509766, target augment loss = 0
# ...

# %%
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/
# Out:
# sending incremental file list
# tensorboardX/
# tensorboardX/.ipynb_checkpoints/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/acc/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/acc/acc/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/acc/acc/test acc/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/acc/acc/train acc/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/loss/
# tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass/Fri May  8 19:28:32 2020/loss/class loss/
# ...

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Dslr' --target='Webcam' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/
# Out:
# /content/Domain_Adaptation
# Source domain :Dslr, Train Data size:498 Test Data size:498
# Target domain :Webcam, Train Data size:795 Test Data size:795
# 476/498
# Data size = 498 , corrects = 15
# loss weight = 1.0
# Initial Train Loss: 0.0000 Acc: 0.0301
#
#
# 784/795
# Data size = 795 , corrects = 22
# loss weight = 1.0
# Initial Test Loss: 0.0000 Acc: 0.0277
#
#
#
# Epoch 0/999998
#  ----------
# iteration : 0
#
# 784/795
#
# Data size = 812 , corrects = 96
# Using 33.169558
# Alpha =  0.021634954242364612
# source loss = 3.811898946762085, target_loss = 3.4103338718414307, target augment loss = 0
# Train Loss: 7.6882 Acc: 0.1182
#
# Cuda : cuda:0 Current Best Test Acc : 0.027673
# Optimizer : SGD Cur lr :  0.00096872471695842
#
#
#
# Epoch 1/999998
#  ----------
# iteration : 29
#
# 784/795
#
# Data size = 812 , corrects = 323
# Using 31.546875
# Alpha =  0.04402099061002618
# source loss = 2.4591031074523926, target_loss = 2.2357873916625977, target augment loss = 0
# ...

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Webcam' --target='Dslr' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
# Epoch 83/999998
#  ----------
# iteration : 1494
#
# 476/498
#
# Data size = 504 , corrects = 496
# Using 18.950414
# Alpha =  0.8235325027709184
# source loss = 0.7342591881752014, target_loss = 0.7436795830726624, target augment loss = 0
# Train Loss: 1.4679 Acc: 0.9841
#
# 476/498
# Data size = 498 , corrects = 498
# loss weight = 1.0
# Test Loss: 0.0000 Acc: 1.0000
#
# New model is better, start saving ......
# Save model in ./models_checkpoints/Office31/WtoD/CyCleMADA_[RTN(RTN(x)+RTN(d))]_noEntropy_noRTNmode_withTargetClass_best_test.pt successfully
#
# successfully save log in ./logs/Office31/WtoD/CyCleMADA_[RTN(RTN(x)+RTN(d))]_noEntropy_noRTNmode_withTargetClass.csv
# Cuda : cuda:0 Current Best Test Acc : 1.000000
# Optimizer : SGD Cur lr :  0.00040517219131640426
#
#
#
# Epoch 84/999998
#  ----------
# iteration : 1512
#
# 476/498
#
# Data size = 504 , corrects = 488
# Using 19.387019
# Alpha =  0.827957794789224
# ...

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Amazon' --target='Dslr' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#
# 476/498
#
# Data size = 504 , corrects = 468
# Using 18.588623
# Alpha =  0.8143724537540169
# source loss = 0.8645487427711487, target_loss = 0.8548359870910645, target augment loss = 0
# Train Loss: 1.7646 Acc: 0.9286
#
# Cuda : cuda:0 Current Best Test Acc : 0.865462
# Optimizer : SGD Cur lr :  0.00041031668355947436
#
#
#
# Epoch 82/999998
#  ----------
# iteration : 1476
#
# 476/498
#
# Data size = 504 , corrects = 463
# Using 18.551596
# Alpha =  0.8190046534945694
# source loss = 0.7447262406349182, target_loss = 0.7531932592391968, target augment loss = 0
# Train Loss: 1.7998 Acc: 0.9187
#
# Cuda : cuda:0 Current Best Test Acc : 0.865462
# Optimizer : SGD Cur lr :  0.0004077255061105423
#
#
#
# Epoch 83/999998
#  ----------
# iteration : 1494
#
# 476/498
#
# Data size = 504 , corrects = 462
# Using 18.608307
# Alpha =  0.8235325027709184
# source loss = 0.7242873907089233, target_loss = 0.8526691198348999, target augment loss = 0
# ...

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Dslr' --target='Amazon' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/
# Out:
# /content/Domain_Adaptation
# Source domain :Dslr, Train Data size:498 Test Data size:498
# Target domain :Amazon, Train Data size:2817 Test Data size:2817
# 476/498
# Data size = 498 , corrects = 15
# loss weight = 1.0
# Initial Train Loss: 0.0000 Acc: 0.0301
#
#
# 2800/2817
# Data size = 2817 , corrects = 64
# loss weight = 1.0
# Initial Test Loss: 0.0000 Acc: 0.0227
#
#
#
# Epoch 0/999998
#  ----------
# iteration : 0
#
# 2800/2817
#
# Data size = 2828 , corrects = 1239
# Using 102.584865
# Alpha =  0.07712627697313601
# source loss = 1.264615535736084, target_loss = 1.7751164436340332, target augment loss = 0
# Train Loss: 5.4651 Acc: 0.4381
#
# Cuda : cuda:0 Current Best Test Acc : 0.022719
# Optimizer : SGD Cur lr :  0.0008978168650264795
#
#
#
# Epoch 1/999998
#  ----------
# iteration : 101
#
# 2800/2817
#
# Data size = 2828 , corrects = 2507
# Using 102.410738
# Alpha =  0.15409495118392647
# ...

# %%
# !python3 main.py --model='CycleMADA' --dataset='Office31' --source='Webcam' --target='Amazon' \
--cuda='cuda:0' --num_workers=0  --iterations=6470 --test_interval=200 --batch_size=28 --loss_weight=1.0
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/

# %%
# !python3 main.py --model='CycleMADA' --dataset='Digits' --source='MNIST' --target='USPS' \
--cuda='cuda:0' --num_workers=0 --epochs=150 --batch_size=256 --test_interval=1 --optimizer='Adam' --loss_weight=0.1

# %%
# !python3 main.py --model='RTNMADA' --dataset='Digits' --source='MNIST' --target='USPS' \
--cuda='cuda:0' --num_workers=0 --epochs=150 --batch_size=256 --test_interval=1 --optimizer='Adam' --loss_weight=0.1

# %%
! rsync -avz /content/Domain_Adaptation/tensorboardX /content/drive/My\ Drive/tensorboardX/
! rsync -avz /content/Domain_Adaptation/models_checkpoints /content/drive/My\ Drive/tensorboardX/

# %%
# !rm -r /content/Domain_Adaptation/tensorboardX/AtoW_CyCleMADA_[x+RTN(x+d)]_noEntropy_noRTNmode_withTargetClass
# !rm -r /content/Domain_Adaptation/models_checkpoints/*
